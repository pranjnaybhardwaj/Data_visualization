# %%
from sjvisualizer import DataHandler

# %%
from sjvisualizer import Canvas

# %%
from sjvisualizer import BarRace

# %%
FPS=60

# %%
DURATION=1

# %%
df = DataHandler.DataHandler(excel_file="C:/Users/pranj/OneDrive/Desktop/export.xlsx", number_of_frames=FPS*DURATION*60).df
# Out:
# Loading cashed data frame _pandas_cache\Users3607.xlsx

# %%
df
# Out:
#                                France       Germany         Italy  \
# 1990-12-31 00:00:00.000  22900.000000  63300.000000  40000.000000
# 1991-01-02 10:19:35.714  22897.071958  63286.557628  39996.539587
# 1991-01-04 20:39:11.428  22894.143917  63273.115255  39993.079175
# 1991-01-07 06:58:47.142  22891.215875  63259.672883  39989.618762
# 1991-01-09 17:18:22.856  22888.287834  63246.230510  39986.158349
# ...                               ...           ...           ...
# 2019-12-31 00:37:55.000  13200.000000  27000.000000  24700.000000
# 2019-12-31 00:38:08.000  13200.000000  27000.000000  24700.000000
# 2019-12-31 00:38:21.000  13200.000000  27000.000000  24700.000000
# 2019-12-31 00:38:34.000  13200.000000  27000.000000  24700.000000
# 2019-12-31 00:38:47.000  13200.000000  27000.000000  24700.000000
#
#                          Netherlands       Norway         Spain       Sweden  \
# 1990-12-31 00:00:00.000  8590.000000  1660.000000  13800.000000  2690.000000
# ...

# %%
canvas = Canvas.canvas()

# %%
bar_race = BarRace.bar_race(canvas=canvas.canvas,df=df)

# %%
canvas.add_sub_plot(bar_race)

# %%
canvas.add_title('Number of deaths due to Particulate Matter')

# %%
canvas.add_time(df=df,time_indicator="year")

# %%
canvas.play(fps=FPS)
# Out:
# FPS: 1
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 58
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 58
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 60
# FPS: 60
# FPS: 60
# FPS: 60
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 60
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 58
# FPS: 58
# FPS: 58
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 60
# FPS: 58
# FPS: 59
# FPS: 58
# FPS: 60
# FPS: 60
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 58
# FPS: 59
# FPS: 59
# FPS: 58
# FPS: 60
# FPS: 42
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 38
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 58
# FPS: 58
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 60
# FPS: 60
# FPS: 58
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 59
# FPS: 58
# FPS: 58
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 60
# FPS: 59
# FPS: 59
# FPS: 58
# ...
